# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 2.6 MB/s eta 0:00:00
# ...

# %%
import snscrape.modules.twitter as snt
import pandas as pd

# %% [markdown]
# Scrape

# %%
# %%time
atributes_container = []

for i, tweet in enumerate(snt.TwitterSearchScraper('the last of us lang:en').get_items()):
  if i==10000:
    break
  atributes_container.append([tweet.date, tweet.likeCount, tweet.replyCount, tweet.retweetCount, tweet.rawContent])
  

tweets_df = pd.DataFrame(atributes_container, columns=['Date Created', 'Number of Likes', 'Replies', 'Retweets', 'Content'])
# Out:
# CPU times: user 8.07 s, sys: 366 ms, total: 8.44 s
# Wall time: 6min 22s

# %%
tweets_df
# Out:
#                   Date Created  Number of Likes  Replies  Retweets  \
# 0    2023-02-11 18:03:31+00:00                0        0         0
# 1    2023-02-11 18:03:29+00:00                0        0         0
# 2    2023-02-11 18:03:28+00:00                0        0         0
# 3    2023-02-11 18:03:27+00:00                0        0         0
# 4    2023-02-11 18:03:19+00:00                0        0         0
# ...                        ...              ...      ...       ...
# 9995 2023-02-11 06:25:01+00:00                0        0         0
# 9996 2023-02-11 06:24:48+00:00               20        1         0
# 9997 2023-02-11 06:24:45+00:00                6        0         0
# 9998 2023-02-11 06:24:42+00:00                0        0         0
# 9999 2023-02-11 06:24:42+00:00               90        2         2
#
#                                                 Content
# 0     🥹😢They’re laying it on thick with the Henry an...
# ...

# %% [markdown]
# Save to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH = '/content/drive/MyDrive/Data Science/Datasets/'
tweets_df.to_csv(PATH+'lastofus10k.csv', header=False, index=False)
